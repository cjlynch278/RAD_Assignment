# %%
import chromadb

from chromadb.utils import embedding_functions

def chroma_setup(simulated_cves):
    """
    Initializes a ChromaDB collection and populates it with CVE data.

    Args:
        simulated_cves (list of dict): List of CVE dictionaries, each with at least 'id' and 'description' keys.

    Returns:
        chromadb.Collection: The populated ChromaDB collection.
    """
    client = chromadb.Client(distance_function="cosine")
    #client.delete_collection("cves")  # Ensure a clean start by deleting any existing collection with the same name
    
    embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")
    # Check if collection already exists

    cve_collection = client.create_collection(
        name="cves",
        embedding_function=embedding_function
    )
    for cve in simulated_cves:
        # Each document must have a unique id and some content
        cve_collection.add(
            documents=[cve['description']],
            ids=[cve['cve_id']],
           # metadatas=[{k: v for k, v in cve.items() if k not in ['id', 'description']}]
        )

    return cve_collection

# %%
client = chromadb.Client()

client.delete_collection("cves")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[12], line 3
#       1 client = chromadb.Client()
# ----> 3 client.delete_collection("cves")
#
# File ~/virtual_envrionments/dev-env/lib/python3.13/site-packages/chromadb/api/client.py:241, in Client.delete_collection(self, name)
#     236 @override
#     237 def delete_collection(
#     238     self,
#     239     name: str,
#     240 ) -> None:
# --> 241     return self._server.delete_collection(
#     242         name=name,
#     243         tenant=self.tenant,
#     244         database=self.database,
#     245     )
#
# File ~/virtual_envrionments/dev-env/lib/python3.13/site-packages/chromadb/api/rust.py:279, in RustBindingsAPI.delete_collection(self, name, tenant, database)
#     272 @override
#     273 def delete_collection(
#     274     self,
#    (...)    277     database: str = DEFAULT_DATABASE,
#     278 ) -> None:
# --> 279     self.bindings.delete_collection(name, tenant, database)
#
# NotFoundError: Collection [cves] does not exists

# %%
import json
json_cves = json.load(open('data/simulated_cves.json'))
chroma_setup = chroma_setup(json_cves)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import json
#       2 json_cves = json.load(open('data/simulated_cves.json'))
# ----> 3 chroma_setup = chroma_setup(json_cves)
#
# Cell In[2], line 15, in chroma_setup(simulated_cves)
#       5 def chroma_setup(simulated_cves):
#       6     """
#       7     Initializes a ChromaDB collection and populates it with CVE data.
#       8
#    (...)     13         chromadb.Collection: The populated ChromaDB collection.
#      14     """
# ---> 15     client = chromadb.Client(distance_function="cosine")
#      16     #client.delete_collection("cves")  # Ensure a clean start by deleting any existing collection with the same name
#      18     embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")
#
# TypeError: Client() got an unexpected keyword argument 'distance_function'

# %%
chroma_setup
# Out:
# <function __main__.chroma_setup(simulated_cves)>

# %%
collection = client.get_collection("cves")  # Ensure the collection is created and returned
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 collection = client.get_collection("cves")  # Ensure the collection is created and returned
#
# File ~/virtual_envrionments/dev-env/lib/python3.13/site-packages/chromadb/api/client.py:178, in Client.get_collection(self, name, embedding_function, data_loader)
#     169 @override
#     170 def get_collection(
#     171     self,
#    (...)    176     data_loader: Optional[DataLoader[Loadable]] = None,
#     177 ) -> Collection:
# --> 178     model = self._server.get_collection(
#     179         name=name,
#     180         tenant=self.tenant,
#     181         database=self.database,
#     182     )
#     183     return Collection(
#     184         client=self._server,
#     185         model=model,
#     186         embedding_function=embedding_function,
#     187         data_loader=data_loader,
#     188     )
#
# File ~/virtual_envrionments/dev-env/lib/python3.13/site-packages/chromadb/api/rust.py:246, in RustBindingsAPI.get_collection(self, name, tenant, database)
#     239 @override
#     240 def get_collection(
#     241     self,
#    (...)    244     database: str = DEFAULT_DATABASE,
#     245 ) -> CollectionModel:
# --> 246     collection = self.bindings.get_collection(name, tenant, database)
#     247     return CollectionModel(
#     248         id=collection.id,
#     249         name=collection.name,
#    (...)    256         database=collection.database,
#     257     )
#
# NotFoundError: Collection [cves] does not exists

# %%
collection
# Out:
# Collection(name=cves)

# %%
collection.get(
            include=["documents", "metadatas", "embeddings"])
# Out:
# {'ids': ['CVE-2023-10004',
#   'CVE-2023-10005',
#   'CVE-2023-10013',
#   'CVE-2023-10012',
#   'CVE-2023-20003',
#   'CVE-2023-10003',
#   'CVE-2023-10010',
#   'CVE-2023-20005',
#   'CVE-2023-10008',
#   'CVE-2023-10002',
#   'CVE-2023-10006',
#   'CVE-2023-10011',
#   'CVE-2023-20004',
#   'CVE-2023-20002',
#   'CVE-2023-10001',
#   'CVE-2023-20001',
#   'CVE-2023-10007',
#   'CVE-2023-10009'],
#  'embeddings': array([[ 0.06672726,  0.08034389,  0.01904949, ..., -0.07227028,
#           0.09423951, -0.01543871],
#         [-0.03736312,  0.04468577,  0.08734924, ..., -0.04294799,
#           0.06059562, -0.03788127],
#         [-0.09218571,  0.02570973,  0.03566836, ..., -0.04854644,
#           0.0746178 , -0.04936385],
#         ...,
#         [-0.0004517 ,  0.02147715,  0.03226284, ...,  0.00942816,
#          -0.03976323, -0.09410153],
#         [-0.03477827, -0.06654688,  0.00742643, ...,  0.01310693,
#          -0.01094077,  0.02288765],
#         [-0.0098493 ,  0.00710027,  0.03457652, ..., -0.02901638,
#           0.10698055, -0.03629577]], shape=(18, 384)),
#  'documents': ['OpenLDAP 2.4.44 injection flaw allows attacker to bypass login logic',
#   'Node.js axios <0.21.1 dependency injection in HTTP requests',
#   'Cisco IOS XE 17.3.4a allows credential stuffing via rate limit bypass',
#   'Microsoft Office 2016 macro execution flaw',
#   'VLC Media Player <3.0.14 NULL pointer dereference',
#   'PostgreSQL 12.7 unauthorized data export using crafted SQL query',
#   'Jinja2 <2.12 template injection leads to RCE',
#   'Fitbit OS allows attacker to cause UI denial of service',
#   'PHP <7.4.3 RCE via unserialized payload',
#   'WordPress <6.0 File Upload Bypass leading to Web Shell deployment',
#   'Django <3.2.10 fails to enforce auth checks on admin routes',
#   'SQLAlchemy 1.4.20 allows second-order SQL injection in ORM filters',
#   'SAP NetWeaver AS memory corruption bug',
#   'Android 12 camera component info leak via malformed JSON',
#   'Apache Struts RCE via crafted request (affects version 2.5.26)',
#   'Intel Network Driver local privilege escalation (Windows Kernel mode)',
#   'FFmpeg 4.2.7 use-after-free in stream decoder',
#   'libxml2 XXE via crafted payload'],
#  'uris': None,
#  'included': ['documents', 'metadatas', 'embeddings'],
#  'data': None,
#  'metadatas': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None]}

# %%
def get_all_books(self):
        return self.collection.get(
            include=["documents", "metadatas", "embeddings"])
        
def get_book_by_id(self, book_id):
    """Retrieves a book from ChromaDB by its unique ID."""
    result = self.books_collection.get(ids=[str(book_id)], include=["documents", "metadatas", "embeddings"])
    return result if result["ids"] else None

def get_book_by_name(self, title):
    """Retrieves books by title (exact match)."""
    results = self.books_collection.query(
        query_texts=[title], n_results=5, include=["documents", "metadatas", "embeddings"]
    )
    return results if results["ids"] else None

# %%
result = collection.query(
    query_texts=["node http injection"],
    n_results=10,
    include=["documents", "metadatas", "embeddings","distances"]
)
result
# Out:
# {'ids': [['CVE-2023-10005',
#    'CVE-2023-10008',
#    'CVE-2023-10004',
#    'CVE-2023-10009',
#    'CVE-2023-10010',
#    'CVE-2023-10001',
#    'CVE-2023-10002',
#    'CVE-2023-10011',
#    'CVE-2023-20002',
#    'CVE-2023-20005']],
#  'embeddings': [array([[-0.03736312,  0.04468577,  0.08734924, ..., -0.04294799,
#            0.06059562, -0.03788127],
#          [-0.03567362,  0.02833466, -0.04559926, ..., -0.0395343 ,
#            0.02270512, -0.05959402],
#          [ 0.06672726,  0.08034389,  0.01904949, ..., -0.07227028,
#            0.09423951, -0.01543871],
#          ...,
#          [-0.01529333, -0.01350744,  0.03915709, ..., -0.05065345,
#            0.09754162, -0.01335557],
#          [-0.06393134,  0.0530535 ,  0.02867098, ...,  0.02907875,
#           -0.03976606,  0.02444128],
#          [-0.04071669,  0.08823731,  0.04908668, ..., -0.06919369,
#            0.07189044,  0.06890141]], shape=(10, 384))],
#  'documents': [['Node.js axios <0.21.1 dependency injection in HTTP requests',
#    'PHP <7.4.3 RCE via unserialized payload',
#    'OpenLDAP 2.4.44 injection flaw allows attacker to bypass login logic',
#    'libxml2 XXE via crafted payload',
#    'Jinja2 <2.12 template injection leads to RCE',
#    'Apache Struts RCE via crafted request (affects version 2.5.26)',
#    'WordPress <6.0 File Upload Bypass leading to Web Shell deployment',
#    'SQLAlchemy 1.4.20 allows second-order SQL injection in ORM filters',
#    'Android 12 camera component info leak via malformed JSON',
#    'Fitbit OS allows attacker to cause UI denial of service']],
#  'uris': None,
#  'included': ['documents', 'metadatas', 'embeddings', 'distances'],
#  'data': None,
#  'metadatas': [[None, None, None, None, None, None, None, None, None, None]],
#  'distances': [[0.9665101766586304,
#    1.4323703050613403,
#    1.4889726638793945,
#    1.578269362449646,
#    1.578721523284912,
#    1.5885372161865234,
#    1.706857442855835,
#    1.7343124151229858,
#    1.7845993041992188,
#    1.8600106239318848]]}

# %%
from db.chroma_functions import *
import json
json_cves = json.load(open('data/simulated_cves.json'))

# %%
collection = chroma_setup(json_cves)
# Out:
# Setting up
# Creating client
# Embeedding function
# Creating Collection
# Adding cve's
# Adding CVE {'cve_id': 'CVE-2023-10004', 'description': 'OpenLDAP 2.4.44 injection flaw allows attacker to bypass login logic', 'affected_software': ['OpenLDAP 2.4.44'], 'cvss_score': 7.8}
# Adding CVE {'cve_id': 'CVE-2023-10005', 'description': 'Node.js axios <0.21.1 dependency injection in HTTP requests', 'affected_software': ['axios 0.21.1'], 'cvss_score': 7.2}
# Adding CVE {'cve_id': 'CVE-2023-10013', 'description': 'Cisco IOS XE 17.3.4a allows credential stuffing via rate limit bypass', 'affected_software': ['Cisco IOS XE 17.3.4a'], 'cvss_score': 6.9}
# Adding CVE {'cve_id': 'CVE-2023-10012', 'description': 'Microsoft Office 2016 macro execution flaw', 'affected_software': ['Microsoft Office 2016'], 'cvss_score': 8.5}
# Adding CVE {'cve_id': 'CVE-2023-20003', 'description': 'VLC Media Player <3.0.14 NULL pointer dereference', 'affected_software': ['VLC Media Player'], 'cvss_score': 4.9}
# Adding CVE {'cve_id': 'CVE-2023-10003', 'description': 'PostgreSQL 12.7 unauthorized data export using crafted SQL query', 'affected_software': ['PostgreSQL 12.7'], 'cvss_score': 8.0}
# Adding CVE {'cve_id': 'CVE-2023-10010', 'description': 'Jinja2 <2.12 template injection leads to RCE', 'affected_software': ['Jinja2 2.11.3'], 'cvss_score': 7.8}
# Adding CVE {'cve_id': 'CVE-2023-20005', 'description': 'Fitbit OS allows attacker to cause UI denial of service', 'affected_software': ['Fitbit OS'], 'cvss_score': 3.5}
# Adding CVE {'cve_id': 'CVE-2023-10008', 'description': 'PHP <7.4.3 RCE via unserialized payload', 'affected_software': ['PHP 7.4.3'], 'cvss_score': 9.1}
# Adding CVE {'cve_id': 'CVE-2023-10002', 'description': 'WordPress <6.0 File Upload Bypass leading to Web Shell deployment', 'affected_software': ['WordPress <6.0'], 'cvss_score': 8.7}
# Adding CVE {'cve_id': 'CVE-2023-10006', 'description': 'Django <3.2.10 fails to enforce auth checks on admin routes', 'affected_software': ['Django 3.2.5'], 'cvss_score': 8.1}
# Adding CVE {'cve_id': 'CVE-2023-10011', 'description': 'SQLAlchemy 1.4.20 allows second-order SQL injection in ORM filters', 'affected_software': ['SQLAlchemy 1.4.20'], 'cvss_score': 8.6}
# Adding CVE {'cve_id': 'CVE-2023-20004', 'description': 'SAP NetWeaver AS memory corruption bug', 'affected_software': ['SAP NetWeaver'], 'cvss_score': 7.6}
# Adding CVE {'cve_id': 'CVE-2023-20002', 'description': 'Android 12 camera component info leak via malformed JSON', 'affected_software': ['Android 12 Camera Stack'], 'cvss_score': 5.0}
# Adding CVE {'cve_id': 'CVE-2023-10001', 'description': 'Apache Struts RCE via crafted request (affects version 2.5.26)', 'affected_software': ['Apache Struts 2.5.26'], 'cvss_score': 9.8}
# Adding CVE {'cve_id': 'CVE-2023-20001', 'description': 'Intel Network Driver local privilege escalation (Windows Kernel mode)', 'affected_software': ['Intel Drivers'], 'cvss_score': 5.4}
# Adding CVE {'cve_id': 'CVE-2023-10007', 'description': 'FFmpeg 4.2.7 use-after-free in stream decoder', 'affected_software': ['FFmpeg 4.2.7'], 'cvss_score': 9.0}
# Adding CVE {'cve_id': 'CVE-2023-10009', 'description': 'libxml2 XXE via crafted payload', 'affected_software': ['libxml2 2.9.10'], 'cvss_score': 7.5}

# %%
result =  query_collection( 'node', collection, n_results=5)

# %%
result = get_all_cves()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 result =get_all_cves()
#
# File ~/Projects/p/RAD_Assignment/db/chroma_functions.py:73, in get_all_cves()
#      72 def get_all_cves():
# ---> 73     return self.collection.get(
#      74         include=["documents", "metadatas", "embeddings"])
#
# NameError: name 'self' is not defined

# %%
for resul in result:
    print(resul)
# Out:
# ids
# embeddings
# documents
# uris
# included
# data
# metadatas
# distances

# %%
result['metadatas']
# Out:
# [[{'affected_software': 'axios 0.21.1', 'cvss_score': 7.2},
#   {'affected_software': 'libxml2 2.9.10', 'cvss_score': 7.5},
#   {'cvss_score': 7.6, 'affected_software': 'SAP NetWeaver'},
#   {'cvss_score': 9.1, 'affected_software': 'PHP 7.4.3'},
#   {'affected_software': 'Jinja2 2.11.3', 'cvss_score': 7.8}]]

# %%
from agent.orchestrator import OrchestratorAgent
orchestrator = OrchestratorAgent()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from agents.orchestrator import OrchestratorAgent
#       2 orchestrator = OrchestratorAgent()
#
# ModuleNotFoundError: No module named 'agents'
